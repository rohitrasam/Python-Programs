# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df = pd.read_csv('data.csv', skipfooter=18007, engine='python')
df = df.drop('ï»¿', axis=1)
df.head()
# Out:
#                 Name  Age Nationality  Potential                 Club  \
# 0           L. Messi   31   Argentina         94         FC Barcelona
# 1  Cristiano Ronaldo   33    Portugal         94             Juventus
# 2          Neymar Jr   26      Brazil         93  Paris Saint-Germain
# 3             De Gea   27       Spain         93    Manchester United
# 4       K. De Bruyne   27     Belgium         92      Manchester City
#
#        Value Preferred Foot       Work Rate Position  Jersey Number  Weight  \
# 0  â‚¬110.5M           Left  Medium/ Medium       RF             10  159lbs
# 1     â‚¬77M          Right       High/ Low       ST              7  183lbs
# 2  â‚¬118.5M          Right    High/ Medium       LW             10  150lbs
# 3     â‚¬72M          Right  Medium/ Medium       GK              1  168lbs
# 4    â‚¬102M          Right      High/ High      RCM              7  154lbs
#
#    Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# ...

# %%
df = df.set_index(['Name'])
df = df.sort_values('Potential', ascending=False)
df.head(10)
# Out:
#                    Age Nationality  Potential                 Club      Value  \
# Name
# K. MbappÃ©          19      France         95  Paris Saint-Germain     â‚¬81M
# L. Messi            31   Argentina         94         FC Barcelona  â‚¬110.5M
# P. Dybala           24   Argentina         94             Juventus     â‚¬89M
# Cristiano Ronaldo   33    Portugal         94             Juventus     â‚¬77M
# Neymar Jr           26      Brazil         93  Paris Saint-Germain  â‚¬118.5M
# De Gea              27       Spain         93    Manchester United     â‚¬72M
# J. Oblak            25    Slovenia         93     AtlÃ©tico Madrid     â‚¬68M
# Gabriel Jesus       21      Brazil         92      Manchester City     â‚¬41M
# Marco Asensio       22       Spain         92          Real Madrid     â‚¬54M
# M. Å kriniar        23    Slovakia         92                Inter   â‚¬46.5M
#
#                   Preferred Foot       Work Rate Position  Jersey Number  \
# Name
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-2d7222ca659e> in <module>
#       1 new_val = 0
#       2 for val in df['Value']:
# ----> 3     if 'M' in val:
#       4         new_val = float(val[3:len(val)-1])
#       5         df['Value'].replace({val:new_val*1000000}, inplace=True)
#
# TypeError: argument of type 'float' is not iterable

# %%
len("â‚¬72M")
# Out:
# 6
